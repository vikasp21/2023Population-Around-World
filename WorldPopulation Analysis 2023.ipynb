# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
sns.set()

# %%
data=pd.read_csv('WorldPopulation2023.csv')
data.head()
# Out:
#   Country, territory or other area   \
# 0                       Afghanistan
# 1                           Albania
# 2                           Algeria
# 3                            Angola
# 4                 Antigua & Barbuda
#
#   Population (estimated mid-year value, millions)                Region  ID  \
# 0                                            42.2          Central Asia   1
# 1                                             2.8                Europe   2
# 2                                            45.6                Africa   3
# 3                                            36.7                Africa   4
# 4                                             0.1  Central & N. America   5
#
#    source: https://www.un-ilibrary.org/content/books/9789210027137/read\nSee the visualization on Information is Beautiful\nhttps://informationisbeautiful.net/visualizations/world-population/
# 0                                                NaN
# ...

# %%
data.drop(columns=['source: https://www.un-ilibrary.org/content/books/9789210027137/read\nSee the visualization on Information is Beautiful\nhttps://informationisbeautiful.net/visualizations/world-population/'
],inplace=True)

# %%
data
# Out:
#     Country, territory or other area  Population                Region   ID
# 0                         Afghanistan       42.2          Central Asia    1
# 1                             Albania        2.8                Europe    2
# 2                             Algeria       45.6                Africa    3
# 3                              Angola       36.7                Africa    4
# 4                   Antigua & Barbuda        0.1  Central & N. America    5
# ..                                ...        ...                   ...  ...
# 199                           Vietnam       98.9             East Asia  200
# 200                    Western Sahara        0.6                Africa  201
# 201                             Yemen       34.4           Middle East  202
# 202                            Zambia       20.6                Africa  203
# 203                          Zimbabwe       16.7                Africa  204
#
# [204 rows x 4 columns]

# %%
data.rename(columns={'Population (estimated mid-year value, millions)':'Population'},inplace=True)

# %%
data.rename(columns={'Country, territory or other area ':'Countries'},inplace=True)

# %%
data.columns
# Out:
# Index(['Countries', 'Population', 'Region', 'ID'], dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 204 entries, 0 to 203
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Countries   204 non-null    object
#  1   Population  204 non-null    object
#  2   Region      204 non-null    object
#  3   ID          204 non-null    int64
# dtypes: int64(1), object(3)
# memory usage: 6.5+ KB

# %%
data.isna().sum()
# Out:
# Countries     0
# Population    0
# Region        0
# ID            0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.describe()
# Out:
#                ID
# count  204.000000
# mean   102.500000
# std     59.033889
# min      1.000000
# 25%     51.750000
# 50%    102.500000
# 75%    153.250000
# max    204.000000

# %%
data.drop(columns=['ID'],inplace=True)

# %%
data.describe()
# Out:
#           Countries Population  Region
# count           204        204     204
# unique          204        140       8
# top     Afghanistan        0.1  Africa
# freq              1         10      58

# %%
data.count().sum()
# Out:
# 612

# %%
data.groupby('Countries').get_group('Afghanistan')
# Out:
#      Countries Population        Region
# 0  Afghanistan       42.2  Central Asia

# %%
data['Region'].unique()
# Out:
# array(['Central Asia', 'Europe', 'Africa', 'Central & N. America',
#        'S. America', 'Oceania', 'Middle East', 'East Asia'], dtype=object)

# %%
data.shape
# Out:
# (204, 3)

# %%
data.nunique()
# Out:
# Countries     204
# Population    140
# Region          8
# dtype: int64

# %%
data['Population'].duplicated(keep=False)
# Out:
# 0      False
# 1       True
# 2      False
# 3       True
# 4       True
#        ...
# 199    False
# 200     True
# 201     True
# 202    False
# 203    False
# Name: Population, Length: 204, dtype: bool

# %%
data
# Out:
#              Countries Population                Region
# 0          Afghanistan       42.2          Central Asia
# 1              Albania        2.8                Europe
# 2              Algeria       45.6                Africa
# 3               Angola       36.7                Africa
# 4    Antigua & Barbuda        0.1  Central & N. America
# ..                 ...        ...                   ...
# 199            Vietnam       98.9             East Asia
# 200     Western Sahara        0.6                Africa
# 201              Yemen       34.4           Middle East
# 202             Zambia       20.6                Africa
# 203           Zimbabwe       16.7                Africa
#
# [204 rows x 3 columns]

# %%
plt.figure(figsize=(20,10))
plt.bar(x=data["Population"],
       height = data["Countries"],
       color="midnightblue")
plt.show()

# %%
plt.figure(figsize=(10,8))
plt.hist(data["Population"])
plt.show()
